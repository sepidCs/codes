# %%
import pandas as pd

# %%
df = pd.read_excel("RMSE-appliances+energy+prediction_0.9_iters_staticpr=10000.xlsx", index_col=0)

df = df[:-4].drop(columns=["TSFRESH"])
df.rename(columns={"no feature selection": "None"}, inplace=True)

# %%
df
# Out:
#          PCA     DiPCA      TRMF  first-order similarities  \
# 0   0.762588  0.871597  0.733487                  0.761948
# 1   0.805986  0.740336  0.845730                  0.663997
# 2   0.841132  0.510726  0.646715                  0.509427
# 3   0.476611  1.308737  1.210393                  0.573913
# 4   1.014091  0.758887  0.747863                  1.284440
# 5   1.056073  0.630996  0.777878                  1.220953
# 6   1.198540  0.698259  0.706714                  0.701269
# 7   0.682980  0.656986  0.851327                  0.721784
# 8   0.707421  0.821104  0.664186                  0.401865
# 9   0.912504  0.651776  0.677987                  0.700695
# 10  0.846203  0.691754  0.729102                  0.724323
# 11  1.876770  0.866834  0.733472                  0.964690
# 12  0.789998  0.717610  0.714303                  0.704950
# 13  0.886474  0.783063  0.738116                  0.694250
# 14  0.759361  1.650259  1.769664                  0.595313
# ...

# %%
import matplotlib.pyplot as plt

# Create a box plot
df.boxplot(figsize=(10, 6))

# Add title and labels
plt.title("Box Plot of RMSE Across Methods for energy = 0.90")
plt.ylabel("RMSE")
plt.xticks(rotation=45)
plt.savefig("boxplot_90.png", dpi=300, bbox_inches='tight')

plt.show()
