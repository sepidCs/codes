# %%
import pandas as pd

# %%
df = pd.read_excel("RMSE-istanbul+stock+exchange_0.95_iters_staticpr=10000.xlsx", index_col=0)
display(df)
df = df[:-4]
df.rename(columns={"no feature selection": "None"}, inplace=True)
# Out:
#            PCA     DiPCA      TRMF  first-order similarities  \
# 0     0.703895  0.770541  0.940607                  0.709074
# 1     1.404250  0.967243  1.164395                  0.923301
# 2     1.196398  0.672301  0.813083                  0.905041
# 3     1.197491  1.161989  1.309349                  1.227127
# 4     1.394421  1.208871  1.069525                  1.084316
# 5     0.940842  0.898928  1.002394                  1.108360
# 6     0.875846  0.724008  0.658197                  0.742469
# 7     1.277046  1.171677  1.030240                  1.065378
# 8     1.311075  0.939980  1.179786                  1.369819
# 9     1.414109  1.297486  1.086736                  1.094597
# Var   0.061546  0.048383  0.035239                  0.042336
# Mean  1.171537  0.981302  1.025431                  1.022948
# Min   0.703895  0.672301  0.658197                  0.709074
# Max   1.414109  1.297486  1.309349                  1.369819
#
# ...

# %%
df
# Out:
#         PCA     DiPCA      TRMF  first-order similarities  \
# 0  0.703895  0.770541  0.940607                  0.709074
# 1  1.404250  0.967243  1.164395                  0.923301
# 2  1.196398  0.672301  0.813083                  0.905041
# 3  1.197491  1.161989  1.309349                  1.227127
# 4  1.394421  1.208871  1.069525                  1.084316
# 5  0.940842  0.898928  1.002394                  1.108360
# 6  0.875846  0.724008  0.658197                  0.742469
# 7  1.277046  1.171677  1.030240                  1.065378
# 8  1.311075  0.939980  1.179786                  1.369819
# 9  1.414109  1.297486  1.086736                  1.094597
#
#    second-order similarities      None
# 0                   1.168835  0.808855
# 1                   1.282763  1.105944
# 2                   1.393520  1.210921
# 3                   1.317396  1.417699
# 4                   0.966629  1.159679
# 5                   0.909664  1.020310
# 6                   0.961312  0.981946
# ...

# %%
import matplotlib.pyplot as plt

# Create a box plot
df.boxplot(figsize=(10, 6))

# Add title and labels
plt.title("Box Plot of RMSE Across Methods for energy = 0.95")
plt.ylabel("RMSE")
plt.xticks(rotation=45)
plt.savefig("boxplot_Istanbul_95.png", dpi=300, bbox_inches='tight')

plt.show()
