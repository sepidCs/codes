# %%
import pandas as pd

# %%
df = pd.read_excel("RMSE-istanbul+stock+exchange_0.85_iters_staticpr=10000.xlsx", index_col=0)
display(df)
df = df[:-4]
df.rename(columns={"no feature selection": "None"}, inplace=True)
# Out:
#            PCA     DiPCA      TRMF  first-order similarities  \
# 0     0.719821  0.774824  0.821793                  0.692894
# 1     1.510220  1.354126  0.811756                  0.892477
# 2     0.986978  0.726313  1.168569                  0.595601
# 3     1.791284  1.548716  1.450452                  1.008325
# 4     1.198555  1.084432  1.262121                  0.865379
# 5     1.105732  1.234655  0.992607                  1.029028
# 6     0.846237  0.690574  0.868721                  0.697427
# 7     1.253120  1.143464  1.151263                  1.028469
# 8     1.337829  1.173998  1.229719                  1.430488
# 9     1.365307  1.542868  1.304662                  1.101598
# Var   0.100407  0.099256  0.048919                  0.059235
# Mean  1.211508  1.127397  1.106166                  0.934169
# Min   0.719821  0.690574  0.811756                  0.595601
# Max   1.791284  1.548716  1.450452                  1.430488
#
# ...

# %%
df
# Out:
#         PCA     DiPCA      TRMF  first-order similarities  \
# 0  0.719821  0.774824  0.821793                  0.692894
# 1  1.510220  1.354126  0.811756                  0.892477
# 2  0.986978  0.726313  1.168569                  0.595601
# 3  1.791284  1.548716  1.450452                  1.008325
# 4  1.198555  1.084432  1.262121                  0.865379
# 5  1.105732  1.234655  0.992607                  1.029028
# 6  0.846237  0.690574  0.868721                  0.697427
# 7  1.253120  1.143464  1.151263                  1.028469
# 8  1.337829  1.173998  1.229719                  1.430488
# 9  1.365307  1.542868  1.304662                  1.101598
#
#    second-order similarities      None
# 0                   1.017464  0.808855
# 1                   1.474797  1.105944
# 2                   1.067976  1.210921
# 3                   1.084262  1.417699
# 4                   0.964699  1.159679
# 5                   1.131384  1.020310
# 6                   0.825647  0.981946
# ...

# %%
import matplotlib.pyplot as plt

# Create a box plot
df.boxplot(figsize=(10, 6))

# Add title and labels
plt.title("Box Plot of RMSE Across Methods for energy = 0.85")
plt.ylabel("RMSE")
plt.xticks(rotation=45)
plt.savefig("boxplot_Istanbul_85.png", dpi=300, bbox_inches='tight')

plt.show()
